# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
out = pd.read_csv('out.csv')
shifted = out+1.5
shifted
# Out:
#             0x        0y        1x        1y        2x        2y        3x  \
# 0     2.969528  1.792635  0.030472  1.792635  0.030472  1.207365  2.969528
# 1     2.966528  1.792637  0.033472  1.792631  0.033472  1.207365  2.966528
# 2     2.963528  1.792635  0.036472  1.792631  0.036472  1.207369  2.963528
# 3     2.960528  1.792638  0.039472  1.792628  0.039472  1.207371  2.960528
# 4     2.957528  1.792648  0.042472  1.792631  0.042472  1.207366  2.957528
# ...        ...       ...       ...       ...       ...       ...       ...
# 1160  0.041491  1.793047  2.956671  1.789120  2.957163  1.206926  0.050375
# 1161  0.041491  1.793047  2.956671  1.789120  2.957163  1.206926  0.047494
# 1162  0.041491  1.793047  2.956671  1.789120  2.957163  1.206926  0.044615
# 1163  0.041491  1.793047  2.956671  1.789120  2.957163  1.206926  0.041735
# 1164  0.041491  1.793047  2.956671  1.789120  2.957163  1.206926  0.041735
#
#             3y  Unnamed: 8
# 0     1.207365         NaN
# ...

# %%
plt.figure(figsize=(5,5))
plt.plot(shifted['1x'],shifted['1y'])
plt.plot(shifted['3x'],shifted['3y'])
plt.xlim(0,3)
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
shifted.to_csv('shifted_wp.csv')
